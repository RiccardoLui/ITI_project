# %% [markdown]
# ## ReadCSV and preprocess

# %%
library(dplyr)
library(readr)
library(rjags)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "package 'rjags' was built under R version 4.4.3"
# Loading required package: coda
#
# Linked to JAGS 4.3.1
#
# Loaded modules: basemod,bugs

# %%
# Read your data
df <- read_csv("data.csv")

# Create team indices (important for modeling)
teams <- sort(unique(c(df$home_team, df$away_team)))
team_index <- setNames(seq_along(teams), teams)

df <- df %>%
  mutate(
    H = team_index[home_team],
    A = team_index[away_team]
  )
# Out:
# Rows: 1230 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): game_date, home_team, away_team
# dbl (12): game_id, fg3m_home, ftm_home, pts_home, fg3m_away, ftm_away, pts_a...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## Model in JAGS for free throws

# %%
model_string_pois <- "
model {
  for (i in 1:N) {
    # Home
    HFT[i] ~ dpois(thetaH[i])
    log(thetaH[i]) <- att[H[i]] + def[A[i]] + c + home
    
    # Away
    AFT[i] ~ dpois(thetaA[i])
    log(thetaA[i]) <- att[A[i]] + def[H[i]] + c
  }

  # Priors
  for (j in 1:K) {
    att[j] ~ dnorm(mu_att, tau_att)
    def[j] ~ dnorm(mu_def, tau_def)
  }

  mu_att ~ dnorm(0, 0.0001)
  mu_def ~ dnorm(0, 0.0001)
  tau_att ~ dgamma(0.1, 0.1)
  tau_def ~ dgamma(0.1, 0.1)

  c ~ dnorm(3, 0.0001)
  home ~ dnorm(0, 0.0001) T(0,)

  # Identifiability constraints
  att[K+1] <- -sum(att[1:(K-1)])
  def[K+1] <- -sum(def[1:(K-1)]) 
}
"

# %% [markdown]
# ## Prepare data for rjags

# %%
# Assume you've already processed your DataFrame as above
data_list <- list(
  N = nrow(df),
  K = length(teams)-1,
  HFT = df$fg2m_home,
  AFT = df$fg2m_away,
  H = df$H,
  A = df$A
)

# Run model
model <- jags.model(textConnection(model_string_pois), data = data_list, n.chains = 3)
update(model, 5000)  # Burn-in

samples_pois <- coda.samples(model, variable.names = c("att", "def", "home", "c"), n.iter = 1000)
summary(samples_pois)
# Out:
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 2460
#    Unobserved stochastic nodes: 64
#    Total graph size: 8476
#
# Initializing model
# Iterations = 6001:7000
# Thinning interval = 1
# Number of chains = 3
# Sample size per chain = 1000
#
# 1. Empirical mean and standard deviation for each variable,
#    plus standard error of the mean:
#
#              Mean       SD  Naive SE Time-series SE
# att[1]  -0.042573 0.019872 3.628e-04      0.0007148
# att[2]   0.019660 0.018638 3.403e-04      0.0006826
# att[3]  -0.043330 0.019959 3.644e-04      0.0007507
# att[4]   0.064485 0.018720 3.418e-04      0.0006058
# att[5]  -0.047614 0.020577 3.757e-04      0.0007741
# att[6]   0.024107 0.019236 3.512e-04      0.0006744
# att[7]   0.003370 0.018208 3.324e-04      0.0006477
# att[8]   0.049764 0.019482 3.557e-04      0.0007320
# att[9]   0.072504 0.018087 3.302e-04      0.0006054
# att[10] -0.063188 0.019876 3.629e-04      0.0006961
# att[11]  0.038130 0.018803 3.433e-04      0.0006349
# att[12] -0.029056 0.020158 3.680e-04      0.0007589
# att[13]  0.095295 0.018362 3.352e-04      0.0006105
# att[14] -0.011251 0.018866 3.445e-04      0.0006142
# att[15] -0.010085 0.019056 3.479e-04      0.0006689
# att[16]  0.004318 0.019294 3.523e-04      0.0007047
# att[17] -0.020508 0.019671 3.591e-04      0.0006962
# att[18] -0.083732 0.020533 3.749e-04      0.0008014
# att[19] -0.061527 0.020037 3.658e-04      0.0007172
# att[20] -0.048999 0.020167 3.682e-04      0.0007762
# att[21]  0.067262 0.018254 3.333e-04      0.0006267
# att[22] -0.153215 0.020288 3.704e-04      0.0007608
# att[23]  0.067295 0.019271 3.518e-04      0.0007406
# att[24]  0.116851 0.018142 3.312e-04      0.0006239
# att[25] -0.030734 0.019793 3.614e-04      0.0007214
# att[26] -0.033261 0.019086 3.485e-04      0.0006370
# att[27] -0.032332 0.019061 3.480e-04      0.0006837
# att[28]  0.039065 0.019164 3.499e-04      0.0007047
# att[29]  0.091225 0.018860 3.443e-04      0.0004846
# att[30]  0.049301 0.019148 3.496e-04      0.0002003
# c        3.393967 0.005118 9.345e-05      0.0002020
# def[1]  -0.005882 0.018713 3.417e-04      0.0006600
# def[2]  -0.091060 0.019766 3.609e-04      0.0006979
# def[3]  -0.065739 0.019551 3.570e-04      0.0007005
# def[4]   0.065219 0.018772 3.427e-04      0.0006400
# def[5]  -0.083840 0.019810 3.617e-04      0.0006901
# def[6]   0.022825 0.019269 3.518e-04      0.0006563
# def[7]  -0.052588 0.019676 3.592e-04      0.0006712
# def[8]  -0.016514 0.019472 3.555e-04      0.0006803
# def[9]   0.118632 0.018487 3.375e-04      0.0006003
# def[10]  0.007176 0.018346 3.350e-04      0.0006237
# def[11]  0.032657 0.019035 3.475e-04      0.0006703
# def[12]  0.065298 0.018315 3.344e-04      0.0006635
# def[13] -0.010290 0.019709 3.598e-04      0.0007034
# def[14] -0.009114 0.019959 3.644e-04      0.0007509
# def[15] -0.064296 0.019761 3.608e-04      0.0007296
# def[16] -0.075867 0.020153 3.679e-04      0.0007620
# def[17]  0.024964 0.017985 3.284e-04      0.0006054
# def[18] -0.059198 0.018883 3.448e-04      0.0005611
# def[19] -0.092960 0.020484 3.740e-04      0.0007591
# def[20]  0.116096 0.017656 3.224e-04      0.0006288
# def[21]  0.077106 0.018530 3.383e-04      0.0005838
# def[22] -0.004549 0.019387 3.540e-04      0.0007025
# def[23] -0.027637 0.019632 3.584e-04      0.0007001
# def[24]  0.059223 0.019626 3.583e-04      0.0007310
# def[25] -0.036884 0.019450 3.551e-04      0.0007081
# def[26]  0.070974 0.018983 3.466e-04      0.0006696
# def[27]  0.007708 0.018931 3.456e-04      0.0006328
# def[28]  0.023672 0.018976 3.464e-04      0.0006734
# def[29] -0.003135 0.019976 3.647e-04      0.0005121
# def[30]  0.004868 0.019643 3.586e-04      0.0002369
# home     0.031773 0.007063 1.289e-04      0.0002872
#
# 2. Quantiles for each variable:
#
#              2.5%       25%       50%       75%     97.5%
# att[1]  -0.082334 -0.055414 -0.042792 -0.029068 -0.003025
# att[2]  -0.018196  0.007554  0.019367  0.032758  0.055417
# att[3]  -0.081329 -0.057579 -0.043551 -0.029491 -0.003414
# att[4]   0.027790  0.051967  0.064625  0.077094  0.100489
# att[5]  -0.089532 -0.061531 -0.047090 -0.033439 -0.007676
# att[6]  -0.014074  0.011276  0.024172  0.036538  0.063071
# att[7]  -0.031962 -0.009231  0.003390  0.015368  0.039697
# att[8]   0.011801  0.036772  0.049335  0.063174  0.088319
# att[9]   0.037091  0.060363  0.072645  0.084234  0.108727
# att[10] -0.101847 -0.076619 -0.063376 -0.049619 -0.023567
# att[11]  0.001063  0.025336  0.038016  0.051093  0.074896
# att[12] -0.069189 -0.042638 -0.029370 -0.015201  0.009697
# att[13]  0.059841  0.082757  0.095175  0.108151  0.129932
# att[14] -0.047824 -0.023426 -0.011074  0.001213  0.024733
# att[15] -0.047459 -0.022170 -0.010245  0.002561  0.027017
# att[16] -0.035467 -0.007518  0.004714  0.017130  0.040295
# att[17] -0.058937 -0.034360 -0.020815 -0.007308  0.018463
# att[18] -0.123966 -0.097931 -0.083777 -0.070144 -0.042192
# att[19] -0.100478 -0.075389 -0.062010 -0.048482 -0.019542
# att[20] -0.088214 -0.062822 -0.048409 -0.035249 -0.008325
# att[21]  0.030227  0.055286  0.067241  0.079724  0.102961
# att[22] -0.193392 -0.167332 -0.152990 -0.139497 -0.114163
# att[23]  0.029522  0.054492  0.067183  0.079998  0.106057
# att[24]  0.080582  0.104425  0.117058  0.129584  0.151685
# att[25] -0.070803 -0.043577 -0.030614 -0.017464  0.006560
# att[26] -0.070028 -0.046745 -0.032697 -0.019914  0.002473
# att[27] -0.070752 -0.045436 -0.032388 -0.019122  0.003200
# att[28]  0.001354  0.025615  0.039388  0.052169  0.074913
# att[29]  0.055555  0.077996  0.091013  0.104246  0.127310
# att[30]  0.011323  0.036594  0.049211  0.062570  0.085426
# c        3.384105  3.390504  3.393989  3.397449  3.404258
# def[1]  -0.041838 -0.018573 -0.005957  0.006537  0.031388
# def[2]  -0.128558 -0.104841 -0.090693 -0.077462 -0.052341
# def[3]  -0.102918 -0.079083 -0.065990 -0.052323 -0.026479
# def[4]   0.028401  0.052797  0.065491  0.078276  0.101608
# def[5]  -0.123470 -0.097331 -0.083661 -0.070464 -0.045603
# def[6]  -0.015725  0.009760  0.022898  0.035844  0.059719
# def[7]  -0.090005 -0.066448 -0.052378 -0.038865 -0.014629
# def[8]  -0.053566 -0.029743 -0.016264 -0.003483  0.020803
# def[9]   0.082249  0.106336  0.119021  0.130987  0.154632
# def[10] -0.029058 -0.005360  0.006983  0.019325  0.043644
# def[11] -0.005804  0.019913  0.032669  0.045459  0.070923
# def[12]  0.028629  0.053499  0.065400  0.077929  0.099899
# def[13] -0.048752 -0.023347 -0.010190  0.002702  0.028132
# def[14] -0.047655 -0.022628 -0.008739  0.004633  0.030426
# def[15] -0.103524 -0.077948 -0.064654 -0.050839 -0.024798
# def[16] -0.117124 -0.089094 -0.075721 -0.061941 -0.036844
# def[17] -0.009507  0.012400  0.024958  0.036897  0.059650
# def[18] -0.096650 -0.071924 -0.058999 -0.046236 -0.022541
# def[19] -0.132498 -0.106204 -0.092927 -0.079257 -0.052732
# def[20]  0.081819  0.104156  0.116283  0.127885  0.149901
# def[21]  0.042347  0.064745  0.076913  0.089536  0.114542
# def[22] -0.042206 -0.017589 -0.004061  0.009176  0.031788
# def[23] -0.066565 -0.040152 -0.027827 -0.014433  0.009792
# def[24]  0.020822  0.045991  0.058951  0.072059  0.098427
# def[25] -0.075609 -0.049710 -0.037052 -0.023882  0.001039
# def[26]  0.034032  0.058255  0.070857  0.083958  0.107846
# def[27] -0.029258 -0.005235  0.007838  0.020537  0.044239
# def[28] -0.014472  0.011536  0.024163  0.035915  0.060965
# def[29] -0.042985 -0.015942 -0.003069  0.009985  0.036022
# def[30] -0.033344 -0.008191  0.004652  0.018323  0.042695
# home     0.018259  0.027174  0.031631  0.036401  0.045523

# %%
#coda::gelman.diag(samples_pois)  # > 1.1, problem with posterior
# Out:
# Error in chol.default(W): the leading minor of order 30 is not positive
# Traceback:
#
# 1. chol(W)
# 2. chol.default(W)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "the leading minor of order 30 is not positive", base::quote(chol.default(W)))

# %%
par(bg = 'white')
plot(samples_pois)
# Out:
# Plot with title "Density of att[4]"
# Plot with title "Density of att[8]"
# Plot with title "Density of att[12]"
# Plot with title "Density of att[16]"
# Plot with title "Density of att[20]"
# Plot with title "Density of att[24]"
# Plot with title "Density of att[28]"
# Plot with title "Density of def[1]"
# Plot with title "Density of def[5]"
# Plot with title "Density of def[9]"
# Plot with title "Density of def[13]"
# Plot with title "Density of def[17]"
# Plot with title "Density of def[21]"
# Plot with title "Density of def[25]"
# Plot with title "Density of def[29]"
# Plot with title "Density of home"

# %%
#jpeg('Pois_FT_trace_density.jpeg')
#par(bg = 'white')
#plot(samples_pois)
#dev.off()

# %% [markdown]
# ## Estimate RMSE

# %%
"   
    # Home
    HFT[i] ~ dpois(thetaH[i])
    log(thetaH[i]) <- att[H[i]] + def[A[i]] + c + home
    
    # Away
    AFT[i] ~ dpois(thetaA[i])
    log(thetaA[i]) <- att[A[i]] + def[H[i]] + c
"
# Out:
# [1] "   \n    # Home\n    HFT[i] ~ dpois(thetaH[i])\n    log(thetaH[i]) <- att[H[i]] + def[A[i]] + c + home\n    \n    # Away\n    AFT[i] ~ dpois(thetaA[i])\n    log(thetaA[i]) <- att[A[i]] + def[H[i]] + c\n"

# %%
N = nrow(df)
K = length(teams)

mean_vals_att <- summary(samples_pois)$statistics[1]
mean_vals_def <- summary(samples_pois)$statistics[32]

for (i in 2:K){
    mean_vals_att <- c(mean_vals_att, summary(samples_pois)$statistics[i])
}

for (j in 33:61){
    mean_vals_def <- c(mean_vals_def, summary(samples_pois)$statistics[j])
}

c_val <- summary(samples_pois)$statistics[31]
home_val <- summary(samples_pois)$statistics[62]

# %%
#write(mean_vals_att, 'Pois_FT_att.txt')
#write(mean_vals_def, 'Pois_FT_def.txt')
#write(c_val, 'Pois_FT_c.txt')
#write(home_val, 'Pois_FT_home.txt')

# %%
write.csv(mean_vals_att, 'Pois_2p_att.csv')
write.csv(mean_vals_def, 'Pois_2p_def.csv')
write.csv(c_val, 'Pois_2p_c.csv')
write.csv(home_val, 'Pois_2p_home.csv')

# %%
# estimate theta[i] ~ exp(att[H[i]] + def[A[i]] + c + home)
theta_1 = exp(mean_vals_att[1] + mean_vals_def[4] + c_val + home_val)
theta_1
# Out:
# [1] 31.44961

# %%
#install.packages("Metrics")
#library(Metrics)

# %%
#actual <- df$ftm_home

#rmse_value <- rmse(actual, predicted)
